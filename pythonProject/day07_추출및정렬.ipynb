# %%
import pandas as pd

# %% [markdown]
# ## 필요한 변수만 추출하기

# %%
exam = pd.read_csv('./input/exam.csv')

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ### 변수 추출하기

# %%
# math 추출
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
# english 추출
exam['english']
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
# 여러 변수 추출하기
exam[['nclass', 'math', 'english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %% [markdown]
# ### 변수 제거하기

# %%
exam.drop(columns='math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
# 여러 변수 제거하기
exam.drop(columns=['math', 'english'])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# ## pandas 함수 조합하기
#
# ### query()와 [] 조합하기

# %%
# nclass가 1인 행만 추출한 다음 english 추출
exam.query('nclass == 1')['english']
# Out:
# 0    98
# 1    97
# 2    86
# 3    98
# Name: english, dtype: int64

# %%
# math가 50 이상인 행만 추출한 다음 id, math 추출
exam.query('math >= 50')[['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
# math가 50 이상인 행만 추출한 다음 id, math 앞부분 5행까지 추출
exam.query('math >= 50')[['id', 'math']].head()
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
# math가 50 이상인 행만 추출한 다음 id, math 앞부분 8행까지 추출
exam.query('math >= 50')[['id', 'math']].head(8)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75

# %% [markdown]
# ### 가독성 있게 코드 줄 바꾸기

# %%
exam.query('math >= 50')\
    [['id', 'math']]\
    .head(8)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75

# %% [markdown]
# ## 순서대로 정렬하기
#
# ### 오름차순으로 정렬하기

# %%
exam.sort_values('math')    # math 오름차순 정렬
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %% [markdown]
# ### 내림차순으로 정렬하기

# %%
exam.sort_values('math', ascending=False)   # math 내림차순 정렬
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %% [markdown]
# ### 여러 정렬 기준 적용하기

# %%
exam.sort_values(['nclass', 'math'])    # nclass 오름차순 -> math 오름차순
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
# nclass 오름차순, math 내림차순 정렬
exam.sort_values(['nclass', 'math'], ascending=[True, False])
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %% [markdown]
# ## 파생변수 추가하기

# %%
# total 변수 추가
exam.assign(total = exam['math'] + exam['english'] + exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %% [markdown]
# ### 여러 파생변수 한번에 추가하기

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = (exam['math'] + exam['english'] + exam['science'])/3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %% [markdown]
# ### assign()에 np.where() 적용하기

# %%
import numpy as np

# %%
exam.assign(test = np.where(exam['science'] >= 60, 'pass', 'fall'))
# Out:
#     id  nclass  math  english  science  test
# 0    1       1    50       98       50  fall
# 1    2       1    60       97       60  pass
# 2    3       1    45       86       78  pass
# 3    4       1    30       98       58  fall
# 4    5       2    25       80       65  pass
# 5    6       2    50       89       98  pass
# 6    7       2    80       90       45  fall
# 7    8       2    90       78       25  fall
# 8    9       3    20       98       15  fall
# 9   10       3    50       98       45  fall
# 10  11       3    65       65       65  pass
# 11  12       3    45       85       32  fall
# 12  13       4    46       98       65  pass
# 13  14       4    48       87       12  fall
# 14  15       4    75       56       78  pass
# 15  16       4    58       98       65  pass
# 16  17       5    65       68       98  pass
# 17  18       5    80       78       90  pass
# 18  19       5    89       68       87  pass
# 19  20       5    78       83       58  fall

# %% [markdown]
# ### 추가한 변수를 pandas 함수에 바로 활용하기

# %%
# total 변수 추가, total 기준으로 오름차순 정렬
exam.assign(total = exam['math'] + exam['english'] + exam['science'])\
    .sort_values('total')
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 2    3       1    45       86       78    209
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# ...

# %% [markdown]
# ### lambda 이용해 데이터 프레임명 줄여쓰기

# %%
long_name = exam.copy()

# %%
long_name.assign(new = long_name['math'] + long_name['english'] + long_name['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %%
# 람다 사용
long_name.assign(new = lambda x: x['math'] + x['english'] + x['science'])
# Out:
#     id  nclass  math  english  science  new
# 0    1       1    50       98       50  198
# 1    2       1    60       97       60  217
# 2    3       1    45       86       78  209
# 3    4       1    30       98       58  186
# 4    5       2    25       80       65  170
# 5    6       2    50       89       98  237
# 6    7       2    80       90       45  215
# 7    8       2    90       78       25  193
# 8    9       3    20       98       15  133
# 9   10       3    50       98       45  193
# 10  11       3    65       65       65  195
# 11  12       3    45       85       32  162
# 12  13       4    46       98       65  209
# 13  14       4    48       87       12  147
# 14  15       4    75       56       78  209
# 15  16       4    58       98       65  221
# 16  17       5    65       68       98  231
# 17  18       5    80       78       90  248
# 18  19       5    89       68       87  244
# 19  20       5    78       83       58  219

# %% [markdown]
# ### 앞에서 만든 변수를 활용해 다시 변수 만들기
# - 반드시 lambda 이용해 데이터 프레임명을 약어로 입력

# %%
exam.assign(total = exam['math'] + exam['english'] + exam['science'],
            mean = lambda x: x['total'] / 3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %%
exam.assign(total = lambda x: x['math'] + x['english'] + x['science'],
            mean = lambda x: x['total'] / 3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# ...

# %% [markdown]
# ## 집단별로 요약하기

# %%
# math 평균 구하기
exam.agg(mean_math = ('math', 'mean'))
# Out:
#             math
# mean_math  57.45

# %%
# nclass 별로 분리하고 math 평균 구하기
exam.groupby('nclass').agg(mean_math = ('math', 'mean'))
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
exam.groupby('nclass', as_index=False).agg(mean_math = ('math', 'mean'))
# Out:
#    nclass  mean_math
# 0       1      46.25
# 1       2      61.25
# 2       3      45.00
# 3       4      56.75
# 4       5      78.00

# %% [markdown]
# ### 여러 요약 통계량 한 번에 구하기

# %%
exam.groupby('nclass')\
    .agg(mean_math = ('math', 'mean'),
         sum_math = ('math', 'sum'),
         median_math = ('math', 'median'),
         n = ('nclass', 'count'))
# Out:
#         mean_math  sum_math  median_math  n
# nclass
# 1           46.25       185         47.5  4
# 2           61.25       245         65.0  4
# 3           45.00       180         47.5  4
# 4           56.75       227         53.0  4
# 5           78.00       312         79.0  4

# %% [markdown]
# ### 모든 변수의 요약 통계량 한 번에 구하기

# %%
exam.groupby('nclass').mean()
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %% [markdown]
# ### 집단별로 다시 집단 나누기

# %%
mpg = pd.read_csv('./input/mpg.csv')

# %%
# 제조회사 및 구동방식별 분리, cty 평균 구하기
mpg.groupby(['manufacturer', 'drv'])\
    .agg(mean_cty = ('cty', 'mean'))
# Out:
#                    mean_cty
# manufacturer drv
# audi         4    16.818182
#              f    18.857143
# chevrolet    4    12.500000
#              f    18.800000
#              r    14.100000
# dodge        4    12.000000
#              f    15.818182
# ford         4    13.307692
#              r    14.750000
# honda        f    24.444444
# hyundai      f    18.642857
# jeep         4    13.500000
# land rover   4    11.500000
# lincoln      r    11.333333
# mercury      4    13.250000
# nissan       4    13.750000
#              f    20.000000
# pontiac      f    17.000000
# subaru       4    19.285714
# toyota       4    14.933333
#              f    21.368421
# volkswagen   f    20.925926

# %%
# audi의 drv별 빈도
mpg.query('manufacturer == "audi"')\
    .groupby(['drv'])\
    .agg(n = ('drv', 'count'))
# Out:
#       n
# drv
# 4    11
# f     7

# %% [markdown]
# ### value_counts()로 집단별 빈도 간단하게 구하기

# %%
mpg['drv'].value_counts()
# Out:
# drv
# f    106
# 4    103
# r     25
# Name: count, dtype: int64

# %%
type(mpg['drv'].value_counts())
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### pandas 함수 조합하기
# - 제조회사별로 'suv' 자동차의 도시 및 고속도로 합산 연비 평균을 구해 내림차순으로 정렬하고, 1~5위까지 출력하기

# %%
mpg.query('category == "suv"')\
    .assign(total = (mpg['hwy'] + mpg['cty']) )\
    .groupby('manufacturer')\
    .agg(mean_total = ('total', 'mean'))\
    .sort_values('mean_total', ascending = False)\
    .head()
# Out:
#               mean_total
# manufacturer
# subaru         43.833333
# toyota         32.625000
# nissan         31.750000
# mercury        31.250000
# jeep           31.125000

# %% [markdown]
# ## 문제
#
# ### Q1. mpg 데이터는 11개 변수로 구성, 이 중 일부만 추출해 분석에 활용하려 함. mpg 데이터에서 category(자동차 종류), cty(도시 연비) 변수를 추출해 새로운 데이터 생성 후 새로 만든 데이터의 일부를 출력해 두 변수로만 구성되어있는지 확인

# %%
mpg_new = mpg[['category', 'cty']]  # category, cty 추출
mpg_new.head()  # mpg_new 일부 출력
# Out:
#   category  cty
# 0  compact   18
# 1  compact   21
# 2  compact   20
# 3  compact   21
# 4  compact   16

# %% [markdown]
# ### Q2. 자동차 종류에 따라 돋시 연비가 어떻게 다른지 알아보기 위해 위에 추출한 데이터를 이용해 category(자동차 종류)가 'suv'인 자동차와 'compact'인 자동차 중 어떤 자동차의 cty(도시 연비) 평균이 더 높은지 확인

# %%
# suv 의 cty 평균
mpg_new.query('category == "suv"')['cty'].mean()
# Out:
# 13.5

# %%
# compact 의 cty 평균
mpg_new.query('category == "compact"')['cty'].mean()
# Out:
# 20.127659574468087

# %% [markdown]
# ## 문제
#
# ### Q1. 'audi'에서 생산한 자동차 중에 어떤 자동차 모델의 hwy(고속도로 연비)가 높은지 알아보기 위해 'audi'에서 생산한 자동차 중 hwy 가 1~5위에 해당하는 자동차의 데이터 출력

# %%
# audi 추출, 내림차순 정렬, 5행까지 출력
mpg.query('manufacturer == "audi"').sort_values('hwy', ascending = False).head()
# Out:
#   manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 2         audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3         audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 0         audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1         audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 9         audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
#
#   category
# 2  compact
# 3  compact
# 0  compact
# 1  compact
# 9  compact

# %% [markdown]
# ## 문제
#
# ### Q1. mpg 데이터 복사본을 만들고, cty와 hwy를 더한 '합산 연비 변수' 추가

# %%
mpg_copy = mpg.copy()   # mpg 복사복 만들기

# 합산 연비 변수 추가
mpg_copy = mpg_copy.assign(total = mpg_copy['cty'] + mpg_copy['hwy'])
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  total
# 0    compact     47
# 1    compact     50
# 2    compact     51
# ...

# %% [markdown]
# ### Q2. '합산 연비 변수'를 2로 나눠 '평균 연비 변수' 추가

# %%
# 평균 연비 변수 추가
mpg_copy = mpg_copy.assign(mean = mpg_copy['total'] / 2)
mpg_copy
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category  total  mean
# 0    compact     47  23.5
# 1    compact     50  25.0
# ...

# %% [markdown]
# ### Q3. '평균 연비 변수'가 가장 높은 자동차 3종의 데이터 출력

# %%
# mean 기준 내림차순 정렬, 상위 3행 출력
mpg_copy.sort_values('mean', ascending = False).head(3)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category  total  mean
# 221  subcompact     79  39.5
# 212     compact     77  38.5
# 222  subcompact     70  35.0

# %% [markdown]
# ### Q4. 1~3번 문제를 해결할 수 있는 하나로 연결된 pandas 구문을 만들어 실행(원본 이용)

# %%
mpg.assign(total = lambda x: x['cty'] + x['hwy'],
           mean = lambda x: x['total'] / 2)\
    .sort_values('mean', ascending = False)\
    .head(3)
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#        category  total  mean
# 221  subcompact     79  39.5
# 212     compact     77  38.5
# 222  subcompact     70  35.0

# %% [markdown]
# ## 문제
#
# ### Q1. mpg 데이터의 category 는 자동차를 특징에 따라 'suv', 'compact' 등 일곱 종류로 분류한 변수. 어떤 차종의 도시 연비가 높은지 비교하기 위해 category별 cty 평균 구하기

# %%
# category 별 분리, cty 평균 구하기
mpg.groupby('category').agg(mean_cty = ('cty', 'mean'))
# Out:
#              mean_cty
# category
# 2seater     15.400000
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# pickup      13.000000
# subcompact  20.371429
# suv         13.500000

# %% [markdown]
# ### Q2. 위 출력 결과는 category 값 알파벳순으로 정렬된 상태. 어떤 차종의 도시 연비가 높은지 쉽게 알아볼 수 있도록 cty 평균이 높은 순으로 정렬

# %%
# category 별 분리, cty 평균 구하기, 내림차순 정렬
mpg.groupby('category')\
    .agg(mean_cty = ('cty', 'mean'))\
    .sort_values('mean_cty', ascending = False)
# Out:
#              mean_cty
# category
# subcompact  20.371429
# compact     20.127660
# midsize     18.756098
# minivan     15.818182
# 2seater     15.400000
# suv         13.500000
# pickup      13.000000

# %% [markdown]
# ### Q3. 어떤 회사 자동차의 hwy(고속도로 연비)가 가장 높은지 알기 위해서 hwy 평균이 가장 높은 회사 세 곳 출력

# %%
# manufacturer 별 분리, hwy 평균 구하기, 내림차순 정렬, 상위 3행 출력
mpg.groupby('manufacturer')\
    .agg(mean_hwy = ('hwy', 'mean'))\
    .sort_values('mean_hwy', ascending = False)\
    .head(3)
# Out:
#                mean_hwy
# manufacturer
# honda         32.555556
# volkswagen    29.222222
# hyundai       26.857143

# %% [markdown]
# ### Q4. 어떤 회사에서 'compact' 차종을 가장 많이 생산하는지 알아보려고 할 때, 회사별 'compact' 차종 수를 내림차순으로 정렬해 출력

# %%
# 방법1
# compact 추출, manufacturer 별 분리, compact 차종 수 구하기, 내림차순 정렬
mpg.query('category == "compact"')\
    .groupby('manufacturer')\
    .agg(n = ('manufacturer', 'count'))\
    .sort_values('n', ascending = False)
# Out:
#                n
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2

# %%
# 방법2
# compact 추출, manufacturer 별 빈도 구하기
mpg.query('category == "compact"')\
    .value_counts('manufacturer')
# Out:
# manufacturer
# audi          15
# volkswagen    14
# toyota        12
# subaru         4
# nissan         2
# Name: count, dtype: int64
